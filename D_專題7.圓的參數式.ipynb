# %% [markdown]
# #圓的參數式

# %% [markdown]
# ##範例1:利用圓的參數式作正多邊形

# %%
#利用圓的參數式作正多邊形
import numpy as np
import matplotlib.pyplot as plt
plt.figure(figsize=(4,4),dpi=80)

pi=3.14159 #圓周率
r=8    #半徑長
N=1    #繞N圈
M=6   #表示M個角
a=0    #起始的偏移角度

t=np.linspace(a+0,a+360*N,M+1)  #參數
t=t*pi/180            #參數,單位轉換
x=r*np.cos(t)          #第一坐標
y=r*np.sin(t)          #第二坐標
plt.plot(x,y,color="red",linewidth=3)

plt.show()

# %% [markdown]
# ##Homework:正多邊形的重疊

# %%
#請參考基本範例,試完成程式碼,結果如下圖

# %% [markdown]
# ##Homework:正多角星形

# %%
#請參考基本範例,試完成程式碼,結果如下圖

# %% [markdown]
# ##Homework:正多邊形的重疊(有塗色)

# %%
#請參考基本範例,試完成程式碼,結果如下圖

# %% [markdown]
# ##範例2:正多邊形的重疊(利用迴圈)

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.figure(figsize=(4,4),dpi=80)

pi=3.14159 #圓周率
r=8    #半徑長
N=1    #繞N圈
M=3   #表示M個角
a=0    #起始的偏移角度
n=10    #迴圈次數
for i in range(0,n,1):
 t=np.linspace(a+0,a+360*N,M+1)  #參數
 t=t*pi/180            #參數,單位轉換
 x=r*np.cos(t)          #第一坐標
 y=r*np.sin(t)          #第二坐標
 plt.plot(x,y,linewidth=3)
 a=a+(360/M/n)

plt.show()

# %% [markdown]
# ##範例3:正多邊形的放大與旋轉(利用迴圈)

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.figure(figsize=(4,4),dpi=80)

pi=3.14159 #圓周率
r=8    #半徑長
N=1    #繞N圈
M=4   #表示M個角
a=0    #起始的偏移角度
n=5    #迴圈次數
for i in range(0,n,1):
 t=np.linspace(a+0,a+360*N,M+1)  #參數
 t=t*pi/180            #參數,單位轉換
 x=r*np.cos(t)          #第一坐標
 y=r*np.sin(t)          #第二坐標
 plt.plot(x,y,linewidth=3)
 a=a+20
 r=r*1.3

plt.show()
