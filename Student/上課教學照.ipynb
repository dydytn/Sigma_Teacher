# %% [markdown]
# #上課照片圖形檔

# %%
from google.colab import files
uploaded=files.upload()

# %%
from PIL import Image
import matplotlib.pyplot as plt
plt.figure(figsize=(9,27),dpi=80)

plt.subplot(3,1,1)    #作圖1
image1=Image.open("m11.JPG")
plt.imshow(image1)

plt.subplot(3,1,2)    #作圖2
image2=Image.open("m12.JPG")
plt.imshow(image2)

plt.subplot(3,1,3)    #作圖3
image3=Image.open("m13.JPG")
plt.imshow(image3)
plt.show()
